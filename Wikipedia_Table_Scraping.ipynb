# %% [markdown]
# ## Webscraping FIFA WC 2026 Group Stage Table

# %%
import requests

url = "https://en.wikipedia.org/wiki/2026_FIFA_World_Cup"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

r = requests.get(url, headers=headers, timeout=15)
print(r.status_code)
print(r.text[:300])
# Out:
# 200
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1

# %%
import requests

api = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "parse",
    "page": "2026_FIFA_World_Cup",
    "prop": "text",
    "format": "json"
}
headers = {"User-Agent": "MyDataProject/1.0 (contact: youremail@example.com)"}

r = requests.get(api, params=params, headers=headers, timeout=15)
print(r.status_code)
data = r.json()
html = data["parse"]["text"]["*"]
# Out:
# 200

# %%
import pandas as pd
import requests

url = "https://en.wikipedia.org/wiki/2026_FIFA_World_Cup"
headers = {"User-Agent": "Mozilla/5.0"}

html = requests.get(url, headers=headers, timeout=15).text
tables = pd.read_html(html)

print("Number of tables:", len(tables))
# Out:
# C:\Users\obinn\AppData\Local\Temp\ipykernel_13416\845858599.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Number of tables: 170

# %%
tables[0].head()
# Out:
#   FIFA World Cup 26Copa Mundial de la FIFA 26Coupe du Monde de la FIFA 26  \
# 0                    We Are 26Somos 26Nous Sommes 26
# 1                                 Tournament details
# 2                                     Host countries
# 3                                              Dates
# 4                                              Teams
#
#   FIFA World Cup 26Copa Mundial de la FIFA 26Coupe du Monde de la FIFA 26.1
# 0                    We Are 26Somos 26Nous Sommes 26
# 1                                 Tournament details
# 2                        Canada Mexico United States
# 3                                  June 11 – July 19
# 4                         48 (from 6 confederations)

# %%
tables[10].head()
# Out:
#   Pos                Team
# 0  A1              Mexico
# 1  A2        South Africa
# 2  A3         South Korea
# 3  A4  UEFA Path D winner

# %%
for idx, df in enumerate(tables):
    rows, cols = df.shape
    colnames = list(df.columns)
    print(f"\nTable index: {idx}")
    print(f"Rows: {rows} | Columns: {cols}")
    print(f"Column names: {colnames}")
# Out:
# Table index: 0
# Rows: 7 | Columns: 2
# Column names: ['FIFA World Cup 26Copa Mundial de la FIFA 26Coupe du Monde de la FIFA 26', 'FIFA World Cup 26Copa Mundial de la FIFA 26Coupe du Monde de la FIFA 26.1']
#
# Table index: 1
# Rows: 8 | Columns: 1
# Column names: [0]
#
# Table index: 2
# Rows: 4 | Columns: 2
# Column names: ['Allowed to vote', 'Ineligible to vote']
#
# Table index: 3
# Rows: 6 | Columns: 2
# Column names: [('Nation', 'Nation'), ('Vote', 'Round 1')]
#
# Table index: 4
# Rows: 1 | Columns: 3
# Column names: [0, 1, 2]
#
# Table index: 5
# Rows: 16 | Columns: 4
# Column names: ['City', 'Stadium', 'Capacity', 'Image']
#
# Table index: 6
# Rows: 64 | Columns: 2
# Column names: ['Training site', 'Hotel']
#
# Table index: 7
# Rows: 1 | Columns: 3
# Column names: [0, 1, 2]
#
# Table index: 8
# Rows: 1 | Columns: 4
# Column names: ['Pot 1', 'Pot 2', 'Pot 3', 'Pot 4']
#
# Table index: 9
# Rows: 63 | Columns: 4
# Column names: [0, 1, 2, 3]
#
# Table index: 10
# ...

# %% [markdown]
# ## Webscraping of largest companies in the united states

# %%
import pandas as pd
import requests

# URL containing the table
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
headers = {"User-Agent": "Mozilla/5.0"}

html = requests.get(url, headers=headers, timeout=15).text
table_list = pd.read_html(html)

print("Number of tables:", len(table_list))
# Out:
# Number of tables: 3
# C:\Users\obinn\AppData\Local\Temp\ipykernel_13416\15097152.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table_list = pd.read_html(html)

# %%
table_1 = table_list[0]
table_1.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3  UnitedHealth Group                  Healthcare
# 3     4               Apple                  Technology
# 4     5          CVS Health                  Healthcare
#
#    Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                  680985           5.1%    2100000     Bentonville, Arkansas
# 1                  637959          11.0%    1556000       Seattle, Washington
# 2                  400278           7.7%     400000     Minnetonka, Minnesota
# 3                  391035           2.0%     164000     Cupertino, California
# 4                  372809           4.2%     259500  Woonsocket, Rhode Island

# %%
table_2 = table_list[1]
table_2.head()
# Out:
#    Rank                   Name       Industry  Revenue (USD billions)  \
# 0     1                Cargill  Food industry                  154.00
# 1     2                   Koch   Multicompany                  125.00
# 2     3   Publix Super Markets   Food Markets                   59.70
# 3     4                   Mars   Food & Drink                   55.00
# 4     5  H-E-B Grocery Company   Food Markets                   49.57
#
#    Employees           Headquarters
# 0     155000  Minnetonka, Minnesota
# 1     120000        Wichita, Kansas
# 2     260000      Lakeland, Florida
# 3     150000       McLean, Virginia
# 4     175000     San Antonio, Texas
